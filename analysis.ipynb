# %%
import pandas as pd

df = pd.read_csv('data/source/cskg.tsv', sep='\t', on_bad_lines='warn')
# Out:
# /var/folders/fz/mfw06hh53blcf3hcdj6s8n3r0000gn/T/ipykernel_46364/1070326950.py:3: ParserWarning: Skipping line 527976: expected 10 fields, saw 11
#
#   df = pd.read_csv('data/source/cskg.tsv', sep='\t', on_bad_lines='warn')
# /var/folders/fz/mfw06hh53blcf3hcdj6s8n3r0000gn/T/ipykernel_46364/1070326950.py:3: ParserWarning: Skipping line 1021767: expected 10 fields, saw 11
#
#   df = pd.read_csv('data/source/cskg.tsv', sep='\t', on_bad_lines='warn')
# /var/folders/fz/mfw06hh53blcf3hcdj6s8n3r0000gn/T/ipykernel_46364/1070326950.py:3: ParserWarning: Skipping line 2266966: expected 10 fields, saw 11
#
#   df = pd.read_csv('data/source/cskg.tsv', sep='\t', on_bad_lines='warn')
# /var/folders/fz/mfw06hh53blcf3hcdj6s8n3r0000gn/T/ipykernel_46364/1070326950.py:3: ParserWarning: Skipping line 2551930: expected 10 fields, saw 11
#
#   df = pd.read_csv('data/source/cskg.tsv', sep='\t', on_bad_lines='warn')
# ...

# %%
df.sample(10)
# Out:
#                                                         id  \
# 3455926    /c/en/sabieite/n-/r/RelatedTo-/c/en/oxygen-0000
# 4080078       /c/en/tinware-/r/DerivedFrom-/c/en/ware-0000
# 2471566  /c/en/micropathologically/r-/r/RelatedTo-/c/en...
# 2257819   /c/en/liberal-/r/Antonym-/c/en/mathematical-0000
# 3764443  /c/en/sphingine/n-/r/RelatedTo-/c/en/amino_alc...
# 2751143  /c/en/oncocytoma/n-/r/RelatedTo-/c/en/benign-0000
# 5405975        fn:fe:affected-fn:HasLexicalUnit-/c/en/time
# 2682068  /c/en/nonphysical_part_predicate/n/opencyc/non...
# 1595488        /c/en/frequent-/r/Synonym-/c/en/common-0000
# 2635517  /c/en/new_iberia/n-/r/RelatedTo-/c/en/louisian...
#
#                                                      node1           relation  \
# 3455926                                   /c/en/sabieite/n       /r/RelatedTo
# 4080078                                      /c/en/tinware     /r/DerivedFrom
# 2471566                        /c/en/micropathologically/r       /r/RelatedTo
# ...

# %%
df[df["relation;label"]== "yellow"]
# Out:
#                                                         id  \
# 16132    /c/en/abrasion/n/wn/state-/r/LocatedNear-/c/en...
# 37072    /c/en/achromatic/a/wn-/r/LocatedNear-/c/en/bel...
# 37139    /c/en/achromatic/a/wn-/r/LocatedNear-/c/en/the...
# 208344   /c/en/around/r/wn-/r/LocatedNear-/c/en/flight/...
# 1191703  /c/en/double/n/wn/act-/r/LocatedNear-/c/en/lin...
# 2210247  /c/en/large/n/wn/attribute-/r/LocatedNear-/c/e...
# 2282684  /c/en/little/n/wn/quantity-/r/LocatedNear-/c/e...
# 2598962  /c/en/narrow/n/wn/object-/r/LocatedNear-/c/en/...
# 2752703  /c/en/one/n/wn/quantity-/r/LocatedNear-/c/en/t...
# 3006973  /c/en/plain/n/wn/object-/r/LocatedNear-/c/en/s...
# 3724131  /c/en/solid/n/wn/substance-/r/LocatedNear-/c/e...
# 4056933  /c/en/three/n/wn/quantity-/r/LocatedNear-/c/en...
# 4199886  /c/en/two/n/wn/quantity-/r/LocatedNear-/c/en/b...
#
#                               node1        relation  \
# 16132     /c/en/abrasion/n/wn/state  /r/LocatedNear
# ...
